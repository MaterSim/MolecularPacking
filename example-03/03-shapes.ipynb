# %% [markdown]
# # Tutorial 3: Packing categorization of shape data
#
# This tutorial discusses how to categorize the crystal packings for the general C-H-N-O type organic crystals. The dataset was from the seminal work by [Motherwell](https://doi.org/10.1107/S0108768189003794).
#
# Created by Qiang Zhu (2022/08/10)
#
# Last updated: 2022/08/10

# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from pyxtal.db import database

# %% [markdown]
# # Clustering anlysis
#
# There are two inputs
# - shape-0.csv: a list of CSD codes
# - shape-0.txt: a square distance matrix
# - shape-1.csv: a list of CSD codes
# - shape-1.txt: a square distance matrix
#
# The files can be obtained by executing `run.py` from the current directory
#
# ```
# python run.py
# ```

# %%
# This should be similar to Fig.8 and Fig. 11 in Motherwell's paper

for i in range(2):
    name = 'shape-'+str(i)
    d0 = pd.read_csv(name+'.csv')
    v0 = 1-np.loadtxt(name+'.txt')
    dists0 = v0[np.triu_indices(v0.shape[0], k = 1)]
    Z0 = linkage(dists0)

    fig = plt.figure(figsize=(25, 6))
    dn = dendrogram(Z0, 
                labels=list(d0['Code']), 
                color_threshold=0.15, 
                above_threshold_color='y',
                show_leaf_counts=True,
                leaf_font_size=22, 
                leaf_rotation=75, 
                show_contracted=True,
                )
    ax = plt.gca()
    ax.set_ylabel('Distance', fontsize=22)
    ax.grid(False)
    ax.tick_params(axis='y', labelsize=22)
    plt.show()

# %% [markdown]
# # Visual analysis
#
# From the above clustering, we can clearly find some crystals are more similar than others.
# In the below, we can simply select two structures and look at the spherica images and real crystal packing.
# Here we choose `PERLEN01` and `QUATER10`. You are welcome to try other pairs.

# %%
db = database('../dataset/shape.db')

code1, code2 = 'RUYKEB', 'RUYKIF'
xtal1 = db.get_pyxtal(code1)
sph1 = xtal1.get_spherical_images()

xtal2 = db.get_pyxtal(code2)
sph2 = xtal2.get_spherical_images()

# %%
sph1.plot_sph_images() #molecule=True)
sph2.plot_sph_images() #molecule=True)

# %%
xtal1.show(size=(400, 200))
# Out:
# <div id="3dmolviewer_166018452059787"  style="position: relative; width: 400px; height: 200px">
#         <p id="3dmolwarning_166018452059787" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_166018452059787 = null;
# var warn = document.getElementById("3dmolwarning_166018452059787");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_166018452059787 = $3Dmol.createViewer($("#3dmolviewer_166018452059787"),{backgroundColor:"white"});
# viewer_166018452059787.zoomTo();
# 	viewer_166018452059787.addModel("#############################################################\n#             ______       _    _          _                #\n#            (_____ \\     \\ \\  / /        | |               #\n#             _____) )   _ \\ \\/ / |_  ____| |               #\n#            |  ____/ | | | )  (|  _)/ _  | |               #\n#            | |    | |_| |/ /\\ \\ |_( (_| | |___            #\n#            |_|     \\__  /_/  \\_\\___)__|_|_____)           #\n#                   (____/                                  #\n#---------------------(version    0.5.1)--------------------#\n#       A Python package for random crystal generation      #\n#       url: https://github.com/qzhu2017/pyxtal             #\n#       @Zhu's group at University of Nevada Las Vegas      #\n#############################################################\ndata_from_pyxtal\n\n_symmetry_space_group_name_H-M 'P21/c'\n_symmetry_Int_Tables_number                   14\n_symmetry_cell_setting                monoclinic\n_cell_length_a            5.084200\n_cell_length_b            5.420200\n_cell_length_c           18.831000\n_cell_angle_alpha        90.000000\n_cell_angle_beta         94.126000\n_cell_angle_gamma        90.000000\n_cell_volume            517.588086\n\nloop_\n _symmetry_equiv_pos_site_id\n _symmetry_equiv_pos_as_xyz\n1 'x, y, z'\n2 '-x, y+1/2, -z+1/2'\n3 '-x, -y, -z'\n4 'x, -y+1/2, z+1/2'\n\nloop_\n _atom_site_label\n _atom_site_type_symbol\n _atom_site_symmetry_multiplicity\n _atom_site_fract_x\n _atom_site_fract_y\n _atom_site_fract_z\n _atom_site_occupancy\nC      C        4    -0.781400   -0.335900    0.355210 1\nC      C        4    -0.828700   -0.160700    0.302450 1\nN      N        4    -0.679300    0.040600    0.295690 1\nC      C        4    -0.476200    0.070600    0.343800 1\nC      C        4    -0.413000   -0.092800    0.400070 1\nC      C        4    -0.570900   -0.303000    0.404360 1\nC      C        4    -0.192900   -0.042800    0.453000 1\nN      N        4    -0.149900   -0.206200    0.506820 1\nN      N        4     0.048200   -0.162500    0.554730 1\nH      H        4    -0.892400   -0.476300    0.357500 1\nH      H        4    -0.975600   -0.184400    0.269000 1\nH      H        4    -0.367500    0.211700    0.339600 1\nH      H        4    -0.533100   -0.421700    0.440800 1\n#END\n\n","cif",{"doAssembly": true, "duplicateAssemblyAtoms": true, "normalizeAssembly": true});
# 	viewer_166018452059787.setStyle({"stick": {"colorscheme": "greenCarbon"}});
# 	viewer_166018452059787.addUnitCell();
# 	viewer_166018452059787.replicateUnitCell(1,1,1);
# 	viewer_166018452059787.zoomTo();
# viewer_166018452059787.render();
# });
# </script>

# %%
xtal2.show(size=(400, 200))
# Out:
# <div id="3dmolviewer_1660184520756906"  style="position: relative; width: 400px; height: 200px">
#         <p id="3dmolwarning_1660184520756906" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_1660184520756906 = null;
# var warn = document.getElementById("3dmolwarning_1660184520756906");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1660184520756906 = $3Dmol.createViewer($("#3dmolviewer_1660184520756906"),{backgroundColor:"white"});
# viewer_1660184520756906.zoomTo();
# 	viewer_1660184520756906.addModel("#############################################################\n#             ______       _    _          _                #\n#            (_____ \\     \\ \\  / /        | |               #\n#             _____) )   _ \\ \\/ / |_  ____| |               #\n#            |  ____/ | | | )  (|  _)/ _  | |               #\n#            | |    | |_| |/ /\\ \\ |_( (_| | |___            #\n#            |_|     \\__  /_/  \\_\\___)__|_|_____)           #\n#                   (____/                                  #\n#---------------------(version    0.5.1)--------------------#\n#       A Python package for random crystal generation      #\n#       url: https://github.com/qzhu2017/pyxtal             #\n#       @Zhu's group at University of Nevada Las Vegas      #\n#############################################################\ndata_from_pyxtal\n\n_symmetry_space_group_name_H-M 'P21/c'\n_symmetry_Int_Tables_number                   14\n_symmetry_cell_setting                monoclinic\n_cell_length_a            5.002900\n_cell_length_b            5.403500\n_cell_length_c           18.788000\n_cell_angle_alpha        90.000000\n_cell_angle_beta         92.776000\n_cell_angle_gamma        90.000000\n_cell_volume            507.303187\n\nloop_\n _symmetry_equiv_pos_site_id\n _symmetry_equiv_pos_as_xyz\n1 'x, y, z'\n2 '-x, y+1/2, -z+1/2'\n3 '-x, -y, -z'\n4 'x, -y+1/2, z+1/2'\n\nloop_\n _atom_site_label\n _atom_site_type_symbol\n _atom_site_symmetry_multiplicity\n _atom_site_fract_x\n _atom_site_fract_y\n _atom_site_fract_z\n _atom_site_occupancy\nC      C        4    -0.781800   -0.308400    0.349090 1\nC      C        4    -0.573900   -0.284500    0.400420 1\nC      C        4    -0.409000   -0.077300    0.398000 1\nC      C        4    -0.458700    0.094000    0.343650 1\nC      C        4    -0.674500    0.055200    0.295810 1\nN      N        4    -0.835800   -0.142000    0.297560 1\nC      C        4    -0.188800   -0.036300    0.452440 1\nN      N        4    -0.041400    0.169900    0.447030 1\nN      N        4     0.153800    0.207100    0.495790 1\nH      H        4    -0.892100   -0.451200    0.350600 1\nH      H        4    -0.545000   -0.406600    0.436300 1\nH      H        4    -0.346900    0.234800    0.339400 1\nH      H        4    -0.709900    0.175600    0.259700 1\n#END\n\n","cif",{"doAssembly": true, "duplicateAssemblyAtoms": true, "normalizeAssembly": true});
# 	viewer_1660184520756906.setStyle({"stick": {"colorscheme": "greenCarbon"}});
# 	viewer_1660184520756906.addUnitCell();
# 	viewer_1660184520756906.replicateUnitCell(1,1,1);
# 	viewer_1660184520756906.zoomTo();
# viewer_1660184520756906.render();
# });
# </script>
