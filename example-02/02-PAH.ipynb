# %% [markdown]
# # Tutorial 2: Packing categorization of PAH data
#
# This tutorial discusses how to categorize the crystal packings for the PAH crystals.
# The dataset was from the seminal work by [Desaraju and Gavezotti](https://doi.org/10.1107/S0108768189003794)
#
# Created by Qiang Zhu (2022/08/10)
#
# Last updated: 2022/08/10

# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from pyxtal.db import database

# %% [markdown]
# # Clustering anlysis
#
# There are two inputs
# - PAH.csv: a list of CSD codes
# - PHA.txt: a 30*30 distance matrix
#
# The files can be obtained by executing `run.py` from the current directory
#
# ```
# python run.py
# ```

# %%
d = pd.read_csv('PAH.csv')
v = 1-np.loadtxt('PAH.txt')
dists = v[np.triu_indices(v.shape[0], k = 1)]
Z = linkage(dists)

fig = plt.figure(figsize=(25, 8))
dn = dendrogram(Z, 
                labels=list(d['Code']), 
                color_threshold=0.15, 
                above_threshold_color='y',
                show_leaf_counts=True,
                leaf_font_size=20, 
                leaf_rotation=75, 
                show_contracted=True,
                )
ax = plt.gca()
ax.set_ylabel('$S$')
ax.tick_params(axis='y', labelsize=20)
ax.grid(False)
plt.show()

# %% [markdown]
# # Visual analysis
#
# From the above clustering, we can clearly find some crystals are more similar than others.
# In the below, we can simply select two structures and look at the spherica images and real crystal packing.
# Here we choose `PERLEN01` and `QUATER10`. You are welcome to try other pairs.

# %%
db = database('../dataset/hydrocarbon.db')

code1, code2 = 'PERLEN01', 'QUATER10'
xtal1 = db.get_pyxtal(code1)
sph1 = xtal1.get_spherical_images()

xtal2 = db.get_pyxtal(code2)
sph2 = xtal2.get_spherical_images()

# %%
sph1.plot_sph_images() #molecule=True)
sph2.plot_sph_images() #molecule=True)

# %%
xtal1.show(size=(400, 200))
# Out:
# <div id="3dmolviewer_1660180594758373"  style="position: relative; width: 400px; height: 200px">
#         <p id="3dmolwarning_1660180594758373" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_1660180594758373 = null;
# var warn = document.getElementById("3dmolwarning_1660180594758373");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1660180594758373 = $3Dmol.createViewer($("#3dmolviewer_1660180594758373"),{backgroundColor:"white"});
# viewer_1660180594758373.zoomTo();
# 	viewer_1660180594758373.addModel("#############################################################\n#             ______       _    _          _                #\n#            (_____ \\     \\ \\  / /        | |               #\n#             _____) )   _ \\ \\/ / |_  ____| |               #\n#            |  ____/ | | | )  (|  _)/ _  | |               #\n#            | |    | |_| |/ /\\ \\ |_( (_| | |___            #\n#            |_|     \\__  /_/  \\_\\___)__|_|_____)           #\n#                   (____/                                  #\n#---------------------(version    0.5.1)--------------------#\n#       A Python package for random crystal generation      #\n#       url: https://github.com/qzhu2017/pyxtal             #\n#       @Zhu's group at University of Nevada Las Vegas      #\n#############################################################\ndata_from_pyxtal\n\n_symmetry_space_group_name_H-M 'P21/c'\n_symmetry_Int_Tables_number                   14\n_symmetry_cell_setting                monoclinic\n_cell_length_a           10.263000\n_cell_length_b           10.826000\n_cell_length_c           11.277000\n_cell_angle_alpha        90.000000\n_cell_angle_beta        100.550000\n_cell_angle_gamma        90.000000\n_cell_volume           1231.775726\n\nloop_\n _symmetry_equiv_pos_site_id\n _symmetry_equiv_pos_as_xyz\n1 'x, y, z'\n2 '-x, y+1/2, -z+1/2'\n3 '-x, -y, -z'\n4 'x, -y+1/2, z+1/2'\n\nloop_\n _atom_site_label\n _atom_site_type_symbol\n _atom_site_symmetry_multiplicity\n _atom_site_fract_x\n _atom_site_fract_y\n _atom_site_fract_z\n _atom_site_occupancy\nC      C        4     0.345000    0.821700    0.566400 1\nC      C        4     0.402100    0.731900    0.645100 1\nC      C        4     0.323900    0.641900    0.684100 1\nC      C        4     0.381600    0.547400    0.762400 1\nC      C        4     0.307000    0.456800    0.800500 1\nC      C        4     0.168300    0.455300    0.763600 1\nC      C        4     0.105000    0.546600    0.685700 1\nC      C        4    -0.038600    0.549300    0.644600 1\nC      C        4    -0.118500    0.457200    0.679600 1\nC      C        4    -0.258200    0.461400    0.641700 1\nC      C        4    -0.317500    0.553000    0.566800 1\nC      C        4    -0.239800    0.645600    0.526600 1\nC      C        4    -0.295900    0.738700    0.448300 1\nC      C        4    -0.219800    0.827400    0.407700 1\nC      C        4    -0.079800    0.828500    0.445300 1\nC      C        4    -0.020400    0.736600    0.525400 1\nC      C        4     0.125100    0.735300    0.565200 1\nC      C        4     0.205700    0.823200    0.526000 1\nC      C        4     0.184200    0.640400    0.645200 1\nC      C        4    -0.099600    0.645200    0.565100 1\nH      H        4     0.412000    0.899000    0.533000 1\nH      H        4     0.512000    0.732000    0.679000 1\nH      H        4     0.493000    0.546000    0.790000 1\nH      H        4     0.367000    0.386000    0.858000 1\nH      H        4     0.108000    0.380000    0.797000 1\nH      H        4    -0.070000    0.386000    0.743000 1\nH      H        4    -0.325000    0.389000    0.673000 1\nH      H        4    -0.423000    0.563000    0.538000 1\nH      H        4    -0.402000    0.736000    0.422000 1\nH      H        4    -0.266000    0.900000    0.347000 1\nH      H        4    -0.016000    0.900000    0.414000 1\nH      H        4     0.161000    0.893000    0.463000 1\n#END\n\n","cif",{"doAssembly": true, "duplicateAssemblyAtoms": true, "normalizeAssembly": true});
# 	viewer_1660180594758373.setStyle({"stick": {"colorscheme": "greenCarbon"}});
# 	viewer_1660180594758373.addUnitCell();
# 	viewer_1660180594758373.replicateUnitCell(1,1,1);
# 	viewer_1660180594758373.zoomTo();
# viewer_1660180594758373.render();
# });
# </script>

# %%
xtal2.show(size=(400, 200))
# Out:
# <div id="3dmolviewer_16601805947764218"  style="position: relative; width: 400px; height: 200px">
#         <p id="3dmolwarning_16601805947764218" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16601805947764218 = null;
# var warn = document.getElementById("3dmolwarning_16601805947764218");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16601805947764218 = $3Dmol.createViewer($("#3dmolviewer_16601805947764218"),{backgroundColor:"white"});
# viewer_16601805947764218.zoomTo();
# 	viewer_16601805947764218.addModel("#############################################################\n#             ______       _    _          _                #\n#            (_____ \\     \\ \\  / /        | |               #\n#             _____) )   _ \\ \\/ / |_  ____| |               #\n#            |  ____/ | | | )  (|  _)/ _  | |               #\n#            | |    | |_| |/ /\\ \\ |_( (_| | |___            #\n#            |_|     \\__  /_/  \\_\\___)__|_|_____)           #\n#                   (____/                                  #\n#---------------------(version    0.5.1)--------------------#\n#       A Python package for random crystal generation      #\n#       url: https://github.com/qzhu2017/pyxtal             #\n#       @Zhu's group at University of Nevada Las Vegas      #\n#############################################################\ndata_from_pyxtal\n\n_symmetry_space_group_name_H-M 'P21/c'\n_symmetry_Int_Tables_number                   14\n_symmetry_cell_setting                monoclinic\n_cell_length_a           19.235000\n_cell_length_b           10.630000\n_cell_length_c           11.145000\n_cell_angle_alpha        90.000000\n_cell_angle_beta        100.460000\n_cell_angle_gamma        90.000000\n_cell_volume           2240.927133\n\nloop_\n _symmetry_equiv_pos_site_id\n _symmetry_equiv_pos_as_xyz\n1 'x, y, z'\n2 '-x, y+1/2, -z+1/2'\n3 '-x, -y, -z'\n4 'x, -y+1/2, z+1/2'\n\nloop_\n _atom_site_label\n _atom_site_type_symbol\n _atom_site_symmetry_multiplicity\n _atom_site_fract_x\n _atom_site_fract_y\n _atom_site_fract_z\n _atom_site_occupancy\nC      C        4     0.404760    0.821400    0.579660 1\nC      C        4     0.441720    0.731310    0.651150 1\nC      C        4     0.405290    0.637240    0.705310 1\nC      C        4     0.442840    0.542550    0.779370 1\nC      C        4     0.407210    0.451250    0.831340 1\nC      C        4     0.333110    0.451780    0.810440 1\nC      C        4     0.293730    0.541920    0.738530 1\nC      C        4     0.216270    0.541690    0.715440 1\nC      C        4     0.177890    0.449260    0.762340 1\nC      C        4     0.105080    0.449580    0.742650 1\nC      C        4     0.064860    0.542290    0.674510 1\nC      C        4    -0.012130    0.543300    0.653380 1\nC      C        4    -0.050130    0.449950    0.699950 1\nC      C        4    -0.123340    0.450200    0.681050 1\nC      C        4    -0.162660    0.543010    0.613320 1\nC      C        4    -0.240390    0.542580    0.593560 1\nC      C        4    -0.278970    0.451520    0.641100 1\nC      C        4    -0.352810    0.452300    0.621790 1\nC      C        4    -0.389860    0.545390    0.554350 1\nC      C        4    -0.353750    0.640430    0.501130 1\nC      C        4    -0.391550    0.735970    0.427310 1\nC      C        4    -0.356480    0.827520    0.375650 1\nC      C        4    -0.282550    0.826830    0.395430 1\nC      C        4    -0.242900    0.736650    0.465990 1\nC      C        4    -0.165440    0.736280    0.487370 1\nC      C        4    -0.126400    0.825600    0.438630 1\nC      C        4    -0.053280    0.826680    0.457430 1\nC      C        4    -0.013500    0.735150    0.528990 1\nC      C        4     0.064010    0.735950    0.550260 1\nC      C        4     0.102000    0.825730    0.499960 1\nC      C        4     0.175080    0.824880    0.519820 1\nC      C        4     0.215090    0.734680    0.590040 1\nC      C        4     0.292660    0.733340    0.610230 1\nC      C        4     0.330580    0.823700    0.559900 1\nC      C        4     0.330520    0.637780    0.685100 1\nC      C        4     0.177890    0.639510    0.643790 1\nC      C        4     0.102300    0.639190    0.623150 1\nC      C        4    -0.050870    0.640400    0.581990 1\nC      C        4    -0.126560    0.640840    0.561250 1\nC      C        4    -0.278500    0.639750    0.520970 1\nH      H        4     0.430000    0.890000    0.544000 1\nH      H        4     0.49900 ...
# 	viewer_16601805947764218.setStyle({"stick": {"colorscheme": "greenCarbon"}});
# 	viewer_16601805947764218.addUnitCell();
# 	viewer_16601805947764218.replicateUnitCell(1,1,1);
# 	viewer_16601805947764218.zoomTo();
# viewer_16601805947764218.render();
# });
# </script>
